# %%
import cv2
import os.path
import tensorflow as tf
import helper
import tests as tests
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
import random
import re
import imageio
import scipy.misc
# Out:
# /anaconda/envs/carnd-term1/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Image read using mpimg.imread
image = mpimg.imread('./data/data_road/training/image_2/um_000000.png')
plt.imshow(image)
print(image.shape)
# Out:
# (375, 1242, 3)

# %%
#Image read using scipy.misc.imread
same_image = scipy.misc.imread('./data/data_road/training/image_2/um_000000.png')
plt.imshow(same_image)
print(same_image.shape)
# Out:
# C:\Users\jj4lhc\AppData\Local\Continuum\anaconda3\envs\carnd-term1\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# (375, 1242, 3)

# %%
#Image read using imageio.imread
same_image_2 = imageio.imread('./data/data_road/training/image_2/um_000000.png')
plt.imshow(same_image_2)
print(same_image_2.shape)
# Out:
# (375, 1242, 3)

# %% [markdown]
# ### Use of batch function to access images

# %%
data_dir = './data/data_road/training'
image_shape = (160, 576)
get_batches_fn = helper.gen_batch_function(data_dir,image_shape)
images, labels =next(get_batches_fn(50))
print(images.shape)
print(labels.shape)
# Out:
# (50, 160, 576, 3)
# (50, 160, 576, 2)

# %%
plt.imshow(images[20])
print(images[20].shape)
# Out:
# (160, 576, 3)
